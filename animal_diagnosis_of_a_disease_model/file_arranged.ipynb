# %%
#ab01, ab04, ch02, ch05, mu02, mu04

import os

didir = "C:/Users/pmp/Desktop/hackaton_dataset - 복사본/D/60/"

cName1 = 'CM_NOR'
cName2 = 'CM_ABN'
cName3 = 'IM_NOR'
cName4 = 'IM_ABN'
cName5 = 'IF_NOR'
cName6 = 'IF_ABN'
cName7 = 'CF_NOR'
cName8 = 'CF_ABN'

dName1 = 'Ab01'
dName2 = 'Ab04'
dName3 = 'Ch02'
dName4 = 'Ch05'
dName5 = 'Mu02'
dName6 = 'Mu04'

i=1

for file_ in os.listdir(didir):
            if "CM" in file_:
                if "NOR" in file_:
                    if "Ab01" in file_:
                        os.rename(didir+file_, didir+str(cName1)+'_'+str(dName1)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ab04" in file_:
                        os.rename(didir+file_, didir+str(cName1)+'_'+str(dName2)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch02" in file_:
                        os.rename(didir+file_, didir+str(cName1)+'_'+str(dName3)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch05" in file_:
                        os.rename(didir+file_, didir+str(cName1)+'_'+str(dName4)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu02" in file_:
                        os.rename(didir+file_, didir+str(cName1)+'_'+str(dName5)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu04" in file_:
                        os.rename(didir+file_, didir+str(cName1)+'_'+str(dName6)+'_'+str(i)+'.jpg')
                        i += 1
                elif "ABN" in file_:
                    if "Ab01" in file_:
                        os.rename(didir+file_, didir+str(cName2)+'_'+str(dName1)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ab04" in file_:
                        os.rename(didir+file_, didir+str(cName2)+'_'+str(dName2)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch02" in file_:
                        os.rename(didir+file_, didir+str(cName2)+'_'+str(dName3)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch05" in file_:
                        os.rename(didir+file_, didir+str(cName2)+'_'+str(dName4)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu02" in file_:
                        os.rename(didir+file_, didir+str(cName2)+'_'+str(dName5)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu04" in file_:
                        os.rename(didir+file_, didir+str(cName2)+'_'+str(dName6)+'_'+str(i)+'.jpg')
                        i += 1
            elif "IM" in file_:
                if "NOR" in file_:
                    if "Ab01" in file_:
                        os.rename(didir+file_, didir+str(cName3)+'_'+str(dName1)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ab04" in file_:
                        os.rename(didir+file_, didir+str(cName3)+'_'+str(dName2)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch02" in file_:
                        os.rename(didir+file_, didir+str(cName3)+'_'+str(dName3)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch05" in file_:
                        os.rename(didir+file_, didir+str(cName3)+'_'+str(dName4)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu02" in file_:
                        os.rename(didir+file_, didir+str(cName3)+'_'+str(dName5)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu04" in file_:
                        os.rename(didir+file_, didir+str(cName3)+'_'+str(dName6)+'_'+str(i)+'.jpg')
                        i += 1
                elif "ABN" in file_:
                    if "Ab01" in file_:
                        os.rename(didir+file_, didir+str(cName4)+'_'+str(dName1)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ab04" in file_:
                        os.rename(didir+file_, didir+str(cName4)+'_'+str(dName2)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch02" in file_:
                        os.rename(didir+file_, didir+str(cName4)+'_'+str(dName3)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch05" in file_:
                        os.rename(didir+file_, didir+str(cName4)+'_'+str(dName4)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu02" in file_:
                        os.rename(didir+file_, didir+str(cName4)+'_'+str(dName5)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu04" in file_:
                        os.rename(didir+file_, didir+str(cName4)+'_'+str(dName6)+'_'+str(i)+'.jpg')
                        i += 1
            elif "IF" in file_:
                if "NOR" in file_:
                    if "Ab01" in file_:
                        os.rename(didir+file_, didir+str(cName5)+'_'+str(dName1)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ab04" in file_:
                        os.rename(didir+file_, didir+str(cName5)+'_'+str(dName2)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch02" in file_:
                        os.rename(didir+file_, didir+str(cName5)+'_'+str(dName3)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch05" in file_:
                        os.rename(didir+file_, didir+str(cName5)+'_'+str(dName4)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu02" in file_:
                        os.rename(didir+file_, didir+str(cName5)+'_'+str(dName5)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu04" in file_:
                        os.rename(didir+file_, didir+str(cName5)+'_'+str(dName6)+'_'+str(i)+'.jpg')
                        i += 1
                elif "ABN" in file_:
                    if "Ab01" in file_:
                        os.rename(didir+file_, didir+str(cName6)+'_'+str(dName1)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ab04" in file_:
                        os.rename(didir+file_, didir+str(cName6)+'_'+str(dName2)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch02" in file_:
                        os.rename(didir+file_, didir+str(cName6)+'_'+str(dName3)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Ch05" in file_:
                        os.rename(didir+file_, didir+str(cName6)+'_'+str(dName4)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu02" in file_:
                        os.rename(didir+file_, didir+str(cName6)+'_'+str(dName5)+'_'+str(i)+'.jpg')
                        i += 1
                    if "Mu04" in file_:
                        os.rename(didir+file_, didir+str(cName6)+'_'+str(dName6)+'_'+str(i)+'.jpg')
                        i += 1
                elif "CF" in file_:
                    if "NOR" in file_:
                        if "Ab01" in file_:
                            os.rename(didir+file_, didir+str(cName7)+'_'+str(dName1)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Ab04" in file_:
                            os.rename(didir+file_, didir+str(cName7)+'_'+str(dName2)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Ch02" in file_:
                            os.rename(didir+file_, didir+str(cName7)+'_'+str(dName3)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Ch05" in file_:
                            os.rename(didir+file_, didir+str(cName7)+'_'+str(dName4)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Mu02" in file_:
                            os.rename(didir+file_, didir+str(cName7)+'_'+str(dName5)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Mu04" in file_:
                            os.rename(didir+file_, didir+str(cName7)+'_'+str(dName6)+'_'+str(i)+'.jpg')
                            i += 1
                    elif "ABN" in file_:
                        if "Ab01" in file_:
                            os.rename(didir+file_, didir+str(cName8)+'_'+str(dName1)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Ab04" in file_:
                            os.rename(didir+file_, didir+str(cName8)+'_'+str(dName2)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Ch02" in file_:
                            os.rename(didir+file_, didir+str(cName8)+'_'+str(dName3)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Ch05" in file_:
                            os.rename(didir+file_, didir+str(cName8)+'_'+str(dName4)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Mu02" in file_:
                            os.rename(didir+file_, didir+str(cName8)+'_'+str(dName5)+'_'+str(i)+'.jpg')
                            i += 1
                        if "Mu04" in file_:
                            os.rename(didir+file_, didir+str(cName8)+'_'+str(dName6)+'_'+str(i)+'.jpg')
                            i += 1
